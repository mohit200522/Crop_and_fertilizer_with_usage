# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/CO2 Emissions_Canada (1).csv')

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# AS6     1324
# AS8     1211
# M6       901
# A6       789
# A8       490
# AM7      445
# A9       339
# AS7      319
# AV       295
# M5       193
# AS10     168
# AM6      132
# AV7      118
# AV6      113
# M7        91
# A5        84
# AS9       77
# A4        65
# AM8       62
# A7        53
# AV8       39
# A10       31
# AS5       26
# AV10      11
# AM5        4
# AM9        3
# AS4        2
# Name: count, dtype: int64

# %%
df['Fuel Type'].value_counts()
# Out:
# Fuel Type
# X    3637
# Z    3202
# E     370
# D     175
# N       1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.head(2)
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
df['Vehicle Class'].value_counts()
# Out:
# Vehicle Class
# SUV - SMALL                 1217
# MID-SIZE                    1133
# COMPACT                     1022
# SUV - STANDARD               735
# FULL-SIZE                    639
# SUBCOMPACT                   606
# PICKUP TRUCK - STANDARD      538
# TWO-SEATER                   460
# MINICOMPACT                  326
# STATION WAGON - SMALL        252
# PICKUP TRUCK - SMALL         159
# MINIVAN                       80
# SPECIAL PURPOSE VEHICLE       77
# VAN - PASSENGER               66
# STATION WAGON - MID-SIZE      53
# VAN - CARGO                   22
# Name: count, dtype: int64

# %%
df['Vehicle Class']=le.fit_transform(df['Vehicle Class'])

# %%
df['Transmission']=le.fit_transform(df['Transmission'])

# %%
df['Fuel Type']=le.fit_transform(df['Fuel Type'])

# %%
df.head()
# Out:
#     Make       Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0  ACURA         ILX              0             2.0          4            14
# 1  ACURA         ILX              0             2.4          4            25
# 2  ACURA  ILX HYBRID              0             1.5          4            22
# 3  ACURA     MDX 4WD             11             3.5          6            15
# 4  ACURA     RDX AWD             11             3.5          6            15
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# 2          4                               6.0
# 3          4                              12.7
# 4          4                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df.drop('Make',axis=1,inplace=True)

# %%
df.drop('Model',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Vehicle Class  Engine Size(L)  Cylinders  Transmission  Fuel Type  \
# 0              0             2.0          4            14          4
# 1              0             2.4          4            25          4
# 2              0             1.5          4            22          4
# 3             11             3.5          6            15          4
# 4             11             3.5          6            15          4
#
#    Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 0                               9.9                              6.7
# 1                              11.2                              7.7
# 2                               6.0                              5.8
# 3                              12.7                              9.1
# 4                              12.1                              8.7
#
#    Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 0                               8.5                           33
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('CO2 Emissions(g/km)',axis=1)
y=df['CO2 Emissions(g/km)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.913888084803667

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb.score(X_test,y_test)*100
# Out:
# 99.75188970565796

# %%
# Explain ann
# Explain forward propogation / backward
# Purpose of hidden layer
# What is weights
# what are activation functions
# What is epochs
# how do you haldel Overfitting in ANN
# What is optimizer and types of it.[Gredient decent , adam]
